# %% [markdown]
# # 07-2 심층 신경망

# %% [markdown]
# 데이터 전처리

# %%
from tensorflow import keras
(train_input, train_target), (test_input, test_target) = keras.datasets.fashion_mnist.load_data()
# Out:
# ...
# 4431872/4422102 [==============================] - 0s 0us/step

# %%
from sklearn.model_selection import train_test_split
train_scaled = train_input / 255.0
train_scaled = train_scaled.reshape(-1, 28*28)
train_scaled, val_scaled, train_target, val_target = train_test_split(train_scaled, train_target, test_size=0.2, random_state=42)

# %% [markdown]
# 심층 신경망

# %% [markdown]
# 1. 배열로 층 전달하기

# %%
dense1 = keras.layers.Dense(100, activation='sigmoid', input_shape=(784,4))
dense2 = keras.layers.Dense(10, activation='softmax')
model = keras.Sequential([dense1, dense2])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 784, 100)          500
#
#  dense_1 (Dense)             (None, 784, 10)           1010
#
# ...
# Total params: 1,510
# Trainable params: 1,510
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# 2. Sequential 클래스의 생성자 안에서 바로 Dense 클래스의 객체 만들기

# %%
model = keras.Sequential([
                        keras.layers.Dense(100, activation='sigmoid', input_shape=(784,), name='hidden'),
                        keras.layers.Dense(10, activation='softmax', name='output')
], name='패션 MNIST 모델')
model.summary()
# Out:
# Model: "패션 MNIST 모델"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  hidden (Dense)              (None, 100)               78500
#
#  output (Dense)              (None, 10)                1010
#
# ...
# Total params: 79,510
# Trainable params: 79,510
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# 3. Sequential 클래스의 add() 메소드 이용

# %%
model = keras.Sequential()
model.add(keras.layers.Dense(100, activation='sigmoid', input_shape=(784,)))
model.add(keras.layers.Dense(10, activation='softmax', name='output'))
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_2 (Dense)             (None, 100)               78500
#
#  output (Dense)              (None, 10)                1010
#
# ...
# Total params: 79,510
# Trainable params: 79,510
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# 모델 훈련

# %%
model.compile(loss='sparse_categorical_crossentropy', metrics='accuracy')
model.fit(train_scaled, train_target, epochs=5)
# Out:
# Epoch 1/5
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.5592 - accuracy: 0.8075
# Epoch 2/5
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.4082 - accuracy: 0.8537
# Epoch 3/5
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.3743 - accuracy: 0.8643
# Epoch 4/5
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.3514 - accuracy: 0.8736
# Epoch 5/5
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.3354 - accuracy: 0.8785

# %% [markdown]
# 렐루(ReLU) 함수 : max(0, z)

# %% [markdown]
# Flatten층 : 입력 데이터를 1차원 배열로 펼치는 전처리 작업을 모델 안에서 실행하는 층

# %%
model = keras.Sequential()
model.add(keras.layers.Flatten(input_shape=(28, 28)))
model.add(keras.layers.Dense(100, activation='relu'))
model.add(keras.layers.Dense(10, activation='softmax'))
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  flatten (Flatten)           (None, 784)               0
#
#  dense_3 (Dense)             (None, 100)               78500
#
#  dense_4 (Dense)             (None, 10)                1010
#
# ...
# Total params: 79,510
# Trainable params: 79,510
# Non-trainable params: 0
# _________________________________________________________________

# %%
(train_input, train_target), (test_input, test_target) = keras.datasets.fashion_mnist.load_data()
train_scaled = train_input / 255.0
train_scaled, val_scaled, train_target, val_target = train_test_split(train_scaled, train_target, test_size=0.2, random_state=42)

# %%
model.compile(loss='sparse_categorical_crossentropy', metrics='accuracy')
model.fit(train_scaled, train_target, epochs=5)
# Out:
# Epoch 1/5
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.5243 - accuracy: 0.8154
# Epoch 2/5
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.3909 - accuracy: 0.8595
# Epoch 3/5
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.3521 - accuracy: 0.8747
# Epoch 4/5
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.3335 - accuracy: 0.8795
# Epoch 5/5
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.3150 - accuracy: 0.8888

# %%
model.evaluate(val_scaled, val_target)
# Out:
# 375/375 [==============================] - 1s 2ms/step - loss: 0.3479 - accuracy: 0.8799
# [0.3478841483592987, 0.8799166679382324]

# %% [markdown]
# 옵티마이저(optimizer)

# %% [markdown]
# SGD

# %%
model.compile(optimizer='sgd', loss='sparse_categorical_crossentropy', metrics='accuracy')

# %%
sgd = keras.optimizers.SGD()
model.compile(optimizer=sgd, loss='sparse_categorical_crossentropy', metrics='accuracy')

# %% [markdown]
# 학습률의 기본값은 0.01인데 이를 변경하고자 할 때 두번째 방법 사용

# %%
sgd = keras.optimizers.SGD(learning_rate=0.1)

# %% [markdown]
# 모멘텀 / 네스테로프 모멘텀

# %%
sgd = keras.optimizers.SGD(momentum=0.9, nesterov=True)

# %% [markdown]
# 적응적 학습률 옵티마이저 : 모델이 최적점에 가까이 갈수록 학습률을 낮추는 방식

# %% [markdown]
# Adagrad

# %%
adagrad = keras.optimizers.Adagrad()
model.compile(optimizer=adagrad, loss='sparse_categorical_crossentropy', metrics='accuracy')

# %% [markdown]
# RMSprop

# %%
rmsprop = keras.optimizers.RMSprop()
model.compile(optimizer=rmsprop, loss='sparse_categorical_crossentropy', metrics='accuracy')

# %% [markdown]
# Adam

# %%
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics='accuracy')

# %% [markdown]
# Adam을 이용해 모델 훈련

# %%
model = keras.Sequential()
model.add(keras.layers.Flatten(input_shape=(28, 28)))
model.add(keras.layers.Dense(100, activation='relu'))
model.add(keras.layers.Dense(10, activation='softmax'))

# %%
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics='accuracy')
model.fit(train_scaled, train_target, epochs=5)
# Out:
# Epoch 1/5
# 1500/1500 [==============================] - 4s 2ms/step - loss: 0.5255 - accuracy: 0.8167
# Epoch 2/5
# 1500/1500 [==============================] - 4s 2ms/step - loss: 0.3952 - accuracy: 0.8586
# Epoch 3/5
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.3546 - accuracy: 0.8705
# Epoch 4/5
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.3252 - accuracy: 0.8804
# Epoch 5/5
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.3066 - accuracy: 0.8873

# %%
model.evaluate(val_scaled, val_target)
# Out:
# 375/375 [==============================] - 1s 2ms/step - loss: 0.3407 - accuracy: 0.8763
# [0.3406752049922943, 0.8763333559036255]
